# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
df = pd.read_csv('Cleaned-Data.csv')

# %%
# Show a few rows
df.head()
# Out:
#    Rank   Mark                 Athlete  Sex              Team   Division  \
# 0     1   9.99            Moore, Devon  Men     Carson-Newman  NCAA D-II
# 1     2  10.07            Lay, Antonio  Men  Central Missouri  NCAA D-II
# 2     3  10.09           Botsio, Isaac  Men    West Texas A&M  NCAA D-II
# 3     4  10.11            Manu, Joseph  Men    West Texas A&M  NCAA D-II
# 4     5  10.15  Charamba, Makanakaishe  Men     Carson-Newman  NCAA D-II
#
#   Event                                  Location       Date  Year  \
# 0  100m  2023 95th Clyde Littlefield Texas Relays  29-Mar-23  2023
# 1  100m  MIAA Outdoor Track & Field Championships   5-May-23  2023
# 2  100m               Jo Meaker Classic and Multi   6-Apr-23  2023
# 3  100m               Jo Meaker Classic and Multi   6-Apr-23  2023
# 4  100m  2023 95th Clyde Littlefield Texas Relays  29-Mar-23  2023
#
#         Points
# 0  1210.320663
# 1  1182.853287
# 2  1176.035703
# 3  1169.237823
# 4  1155.701175

# %%
# Brief description of the data
df.describe()
# Out:
#                 Rank           Mark           Year         Points
# count  292884.000000  292884.000000  292884.000000  292884.000000
# mean       48.996818     199.546287    2016.502291     840.764092
# std        28.785451     453.241021       4.074270     219.137036
# min         1.000000       0.150000    2010.000000    -244.101913
# 25%        24.000000      10.440000    2013.000000     681.996035
# 50%        48.000000      25.300000    2016.000000     866.420994
# 75%        74.000000     112.932500    2020.000000    1006.702287
# max       100.000000    3036.730000    2024.000000    1355.076389

# %%
print(df.isnull().sum())
# Out:
# Rank        0
# Mark        0
# Athlete     6
# Sex         0
# Team        0
# Division    0
# Event       0
# Location    0
# Date        0
# Year        0
# Points      0
# dtype: int64

# %%
events = ['100m', '200m', '400m', '800m', '1500m', '5000m', '10000m', 'Triple Jump', 'High Jump', 'Long Jump', 'Shot Put', 'Discus', 'Javelin']  # Add the events to include

plt.figure(figsize=(10, 6))  # Adjust the figure size if needed


for event in events:
    filtered_df_event = df[(df['Sex'] == 'Women') & (df['Division'] == 'NCAA D-II') & (df['Event'] == event)]
    average_points_event = filtered_df_event.groupby('Year')['Points'].mean()
    plt.plot(average_points_event.index, average_points_event.values, label=event)

plt.xlabel('Year')
plt.ylabel('Average Points')
plt.title('Average Points for Women, NCAA D-II, and Various Events')
plt.legend()
plt.show()

# %%
events = ['100m', '200m', '400m', '800m', '1500m', '5000m', '10000m', 'Triple Jump', 'High Jump', 'Long Jump', 'Shot Put', 'Discus', 'Javelin']  # Add the events to include

plt.figure(figsize=(10, 6))  # Adjust the figure size if needed

df = df[df['Year'] != 2020]

for event in events:
    filtered_df_event = df[(df['Sex'] == 'Women') & (df['Division'] == 'NCAA D-II') & (df['Event'] == event)]
    average_points_event = filtered_df_event.groupby('Year')['Points'].mean()
    plt.plot(average_points_event.index, average_points_event.values, label=event)

plt.xlabel('Year')
plt.ylabel('Average Points')
plt.title('Average Points for Women, NCAA D-II, and Various Events')
plt.legend()
plt.show()

# %%
events = ['100m', '200m', '400m', '800m', '1500m', '5000m', '10000m', 'Pole Vault',
          'Triple Jump', 'High Jump', 'Long Jump', 'Shot Put', 'Discus', 'Javelin'
          ]  # Add the events to include

plt.figure(figsize=(10, 6))  # Adjust the figure size if needed

df = df[df['Year'] != 2020]
df = df[df['Year'] != 2024]


for event in events:
    filtered_df_event = df[(df['Sex'] == 'Men') & (df['Division'] == 'World') & (df['Event'] == event)]
    average_points_event = filtered_df_event.groupby('Year')['Points'].mean()
    plt.plot(average_points_event.index, average_points_event.values, label=event)

plt.xlabel('Year')
plt.ylabel('Average Points')
plt.title('Average Points for Men, Worldwide, and Various Events')
plt.ylim(1100, 1210)  # Set the Y-axis range
plt.legend()
plt.show()

# %% [markdown]
# 1. It appears that there is a general upward trend
# 2. It also appears to align its peaks with the olympic cycle, with several events peaking during olympic years
# 3. Field events are lagging behind, with only pole vault ranking ahead of any running events

# %%
events = ['800m', '1500m', '5000m', '10000m']  # Add the events to include

plt.figure(figsize=(10, 6))  # Adjust the figure size if needed

df = df[df['Year'] != 2020]
df = df[df['Year'] != 2024]


for event in events:
    filtered_df_event = df[(df['Sex'] == 'Men') & (df['Division'] == 'World') & (df['Event'] == event)]
    average_points_event = filtered_df_event.groupby('Year')['Points'].mean()
    plt.plot(average_points_event.index, average_points_event.values, label=event)

plt.xlabel('Year')
plt.ylabel('Average Points')
plt.title('Average Points for Men, Worldwide, and Distance Events')
plt.ylim(1100, 1210)  # Set the Y-axis range
plt.axvline(x=2018.5, color='black', linestyle='-', linewidth=1)
plt.text(2018.5, 1110, 'introduction of dragonfly spike', ha='center', va='top', color='black')
plt.legend()
plt.show()

# %% [markdown]
# 1. The olympic cycle seems to heavily impact the 10000m
# 2. All distance events have seen growth since 2018

# %%
events = ['100m', '200m', '400m']  # Add the events to include

plt.figure(figsize=(10, 6))  # Adjust the figure size if needed

df = df[df['Year'] != 2020]
df = df[df['Year'] != 2024]


for event in events:
    filtered_df_event = df[(df['Sex'] == 'Men') & (df['Division'] == 'World') & (df['Event'] == event)]
    average_points_event = filtered_df_event.groupby('Year')['Points'].mean()
    plt.plot(average_points_event.index, average_points_event.values, label=event)

plt.xlabel('Year')
plt.ylabel('Average Points')
plt.title('Average Points for Men, Worldwide, and Sprint Events')
plt.ylim(1100, 1210)  # Set the Y-axis range
plt.legend()
plt.show()

# %% [markdown]
# 1. Sprints saw significant growth between 2011 and 2016

# %%
events = ['Triple Jump', 'High Jump', 'Long Jump', 'Shot Put', 'Discus', 'Javelin']  # Add the events to include

plt.figure(figsize=(10, 6))  # Adjust the figure size if needed

df = df[df['Year'] != 2020]
df = df[df['Year'] != 2024]


for event in events:
    filtered_df_event = df[(df['Sex'] == 'Men') & (df['Division'] == 'World') & (df['Event'] == event)]
    average_points_event = filtered_df_event.groupby('Year')['Points'].mean()
    plt.plot(average_points_event.index, average_points_event.values, label=event)

plt.xlabel('Year')
plt.ylabel('Average Points')
plt.title('Average Points for Men, Worldwide, and Field Events')
plt.ylim(1100, 1210)  # Set the Y-axis range
plt.legend()
plt.show()

# %% [markdown]
# 1. Field events, with the exception of shot put, have been relatively stagnant since 2010

# %%
divisions = ['NCAA D-I', 'NCAA D-II', 'NCAA D-III', 'World', 'NAIA', 'Kansas 1A', 'Kansas 3A', 'Kansas 6A']  # Add the divisions to include

plt.figure(figsize=(10, 10))  # Adjust the figure size if needed

df = df[df['Year'] != 2020]
df = df[df['Year'] != 2024]
df = df[df['Year'] != 2010]
df = df[df['Year'] != 2011]
df = df[df['Year'] != 2012]


for division in divisions:
    filtered_df_event = df[(df['Sex'] == 'Men') & (df['Division'] == division) & (df['Event'] == '1500m')]
    average_points_event = filtered_df_event.groupby('Year')['Points'].mean()
    plt.plot(average_points_event.index, average_points_event.values, label=division)

for division in divisions:
    filtered_df_event = df[(df['Sex'] == 'Men') & (df['Division'] == division) & (df['Event'] == '1600m')]
    average_points_event = filtered_df_event.groupby('Year')['Points'].mean()
    plt.plot(average_points_event.index, average_points_event.values, label=division)

plt.xlabel('Year')
plt.ylabel('Average Points')
plt.title('Average Points for Men 1500m, All Divisions')
#plt.ylim(1100, 1210)  # Set the Y-axis range
plt.axvline(x=2018.5, color='black', linestyle='-', linewidth=1)
plt.text(2018.5, 1110, 'introduction of dragonfly spike', ha='center', va='top', color='black')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 16))  # Adjust the figure size if needed

divisions = ['World', 'NCAA D-I', 'NCAA D-II', 'NCAA D-III', 'NAIA', 'Kansas 1A', 'Kansas 3A', 'Kansas 6A']

for division in divisions:
    filtered_df_division = df[(df['Sex'] == 'Men') & (df['Division'] == division)]
    average_points_division = filtered_df_division.groupby('Year')['Points'].mean()
    plt.plot(average_points_division.index, average_points_division.values, label=division)

plt.xlabel('Year')
plt.ylabel('Average Points')
plt.title('Average Points for Men, All Divisions, All Events')
plt.legend()
plt.show()

# %% [markdown]
# 1. As expected, there is significant gap between high school, college, and professional levels.
#
#     *Note - High school marks are only state-wide, college marks are only nationwide, and professional marks are worldwide, which may widen these gaps
# 2. Collegiate marks have seen the most improvement overall
# 3. Every division has seen improvement in both 2022 and 2023.
# 4. Kansas 1A is the only division to have a lower average in 2023 than 2010.

# %%
filtered_df = df[(df['Year'] == 2014) & (df['Event'] == '800m') & (df['Sex'] == 'Women') & (df['Division'] == 'NCAA D-I')]
marks = filtered_df['Mark']

plt.hist(marks, bins=10)
plt.xlabel('Time (seconds)')
plt.ylabel('Frequency')
plt.title('Histogram of Results for 2014, 800m, Female, NCAA D-I')
plt.gca().invert_xaxis()  # Flip the x-axis
plt.show()

# %% [markdown]
# - Is average top-100 mark a good measure?
# - Histogram shows how there are no left-side outliers

# %%
filtered_df = df[(df['Division'] == 'NCAA D-I')]

# Convert 'Date' to datetime
filtered_df['Date'] = pd.to_datetime(filtered_df['Date'])

# Create a crosstab heatmap
heatmap_data = pd.crosstab(filtered_df['Date'].dt.month, filtered_df['Date'].dt.day)

# Plot
plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, cmap='Blues')
plt.title('Heatmap of Performance Frequency by Month and Day')
plt.xlabel('Day')
plt.ylabel('Month')
plt.show()
# Out:
# C:\Users\mattg\AppData\Local\Temp\ipykernel_4460\1476532436.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   filtered_df['Date'] = pd.to_datetime(filtered_df['Date'])
# C:\Users\mattg\AppData\Local\Temp\ipykernel_4460\1476532436.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Date'] = pd.to_datetime(filtered_df['Date'])

# %% [markdown]
# This is a disappointing discovery. It was anomalous to see NCAA athletes not setting personal bests at the end of May and into June. However, it seems that TFRRS does not include the NCAA Championships in their performance lists. While unfortunate, it is at least uniform and complete among the collegiate entries.

# %%
filtered_df = df[(df['Division'] == 'World')]

# Convert 'Date' to datetime
filtered_df['Date'] = pd.to_datetime(filtered_df['Date'])
heatmap_data = pd.crosstab(filtered_df['Date'].dt.month, filtered_df['Date'].dt.day)

# Plot
plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, cmap='Blues')
plt.title('Heatmap of Performance Frequency by Month and Day')
plt.xlabel('Day')
plt.ylabel('Month')
plt.show()
# Out:
# C:\Users\mattg\AppData\Local\Temp\ipykernel_4460\2555010457.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   filtered_df['Date'] = pd.to_datetime(filtered_df['Date'])
# C:\Users\mattg\AppData\Local\Temp\ipykernel_4460\2555010457.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Date'] = pd.to_datetime(filtered_df['Date'])

# %%
df_filtered = df[(df['Event'] == '400m') & (df['Sex'] == 'Women') & (df['Division'] == 'NCAA D-I')]

# Calculate maximum and minimum marks for each year
max_marks = df_filtered.groupby('Year')['Mark'].max()
min_marks = df_filtered.groupby('Year')['Mark'].min()
average_marks = df_filtered.groupby('Year')['Mark'].mean()

# Plotting
plt.figure(figsize=(10, 6))  # Adjust figure size if needed

# Plot top and bottom lines
plt.plot(max_marks.index, max_marks.values, color='gray', alpha=0.3, linestyle='-', label='Top Mark')
plt.plot(min_marks.index, min_marks.values, color='gray', alpha=0.3, linestyle='-', label='#100 Mark')

# Fill area between top and bottom lines with dark grey shade
plt.fill_between(max_marks.index, min_marks.values, max_marks.values, color='darkgray', alpha=0.5)

# Plot average line
plt.plot(average_marks.index, average_marks.values, color='black', linestyle='-', label='Average of top 100')

plt.xlabel('Year')
plt.ylabel('Mark')
plt.title("Top and Bottom Marks by Year (D1 Women's 400m)")
plt.legend()
plt.grid(True)
plt.gca().invert_yaxis()  # Invert y-axis
plt.tight_layout()
plt.show()

# %% [markdown]
# This shows both the top mark and 100th mark in relation to the average.

# %%
df_filtered = df[(df['Event'] == '1500m') & (df['Sex'] == 'Women') & (df['Division'] == 'NCAA D-I')]
average_marks = df_filtered.groupby('Year')['Mark'].mean()

plt.figure(figsize=(12, 6))  # Adjust figure size if needed

# Loop through each year and plot marks vertically
for year, group in df_filtered.groupby('Year'):
    marks = group['Mark']
    plt.eventplot(marks, orientation='vertical', lineoffsets=year, colors='black', linewidths=0.5)

plt.plot(average_marks.index, average_marks.values, color='red', linestyle='-', label='Average of top 100')
plt.xlabel('Year')
plt.ylabel('Performance (seconds)')
plt.title("NCAA D-I Women's 1500m Marks by Year")
plt.grid(axis='y')
plt.gca().invert_yaxis()  # Invert y-axis to have the years in ascending order
plt.tight_layout()
plt.show()

# %% [markdown]
# This is a better visualization, since it shows where each mark lies.

# %%
df = pd.read_csv('top100avg_series_diff.csv')
df.head()
# Out:
#      Division    Sex Event  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0    NCAA D-I    Men  100m     0    16    17     9    22    27    20    43
# 1    NCAA D-I  Women  100m     0    21    10    10    16    19    28    33
# 2   NCAA D-II    Men  100m     0    17    14    28     9    23    35    40
# 3   NCAA D-II  Women  100m     0    27    19    25    25    33    29    48
# 4  NCAA D-III    Men  100m     0     4    22    10    27    24    28    30
#
#    2018  2019  2021  2022  2023
# 0    39    39    43    71    68
# 1    45    27    34    48    57
# 2    35    33    34    67    84
# 3    45    54    52    65    80
# 4    28    37    29    76    75

# %%
events = ['100m', '200m', '400m', '800m', '1500m', '5000m', '10000m', 'Pole Vault',
          'Triple Jump', 'High Jump', 'Long Jump', 'Shot Put', 'Discus', 'Javelin'
          ]  # Add the events to include

plt.figure(figsize=(10, 6))  # Adjust the figure size if needed

for event in events:
    filtered_df_event = df[(df['Sex'] == 'Women') & (df['Division'] == 'World') & (df['Event'] == event)]
    values = filtered_df_event.loc[:, '2010':'2023'].values.flatten()  # Select the columns from '2010' to '2023' and flatten the values
    if values.size > 0:  # Check if values is not empty
        plt.plot((2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2021,2022,2023), values, label=event)


plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Difference in Global Point Values for Women since 2010')
plt.legend()
plt.show()
